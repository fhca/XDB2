# %% [markdown]
# https://www.youtube.com/watch?v=0CFFTJUZ2dc

# %% [markdown]
# https://github.com/jonathanrocher/pandas_tutorial

# %% [markdown]
# `sudo pip3 install html5lib
# sudo pip3 install bs4`

# %%
# %matplotlib inline

# %%
import pandas as pd

# %%
from pandas import set_option
set_option("display.max_rows", 16)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# %cd pandas_tutorial-master/demos/climate_timeseries/
# Out:
# /Users/fhca/XDB2/pandas_tutorial-master/demos/climate_timeseries

# %%
# %ls
# Out:
# climate_timeseries.ipynb* data/

# %%
filename = "data/temperatures/annual.land_ocean.90S.90N.df_1901-2000mean.dat"

# %%
full_globe_temp = pd.read_table(filename, sep='\s+', names=["year", "mean_temp"], index_col=0, parse_dates=True)

# %%
full_globe_temp
# Out:
#             mean_temp
# year
# 1880-01-01    -0.1591
# 1881-01-01    -0.0789
# 1882-01-01    -0.1313
# 1883-01-01    -0.1675
# 1884-01-01    -0.2485
# 1885-01-01    -0.2042
# 1886-01-01    -0.1695
# 1887-01-01    -0.2505
# ...               ...
# 2003-01-01     0.5818
# 2004-01-01     0.5416
# 2005-01-01     0.6154
# 2006-01-01     0.5601
# 2007-01-01     0.5472
# 2008-01-01     0.4804
# 2009-01-01     0.5551
# 2010-01-01  -999.0000
#
# [131 rows x 1 columns]

# %%
mp=pd.read_table("data/temperatures/GLB.Ts+dSST.txt", sep='\s+', skiprows=7, skip_footer=11,
             engine="python", parse_dates=[1])
mp
# Out:
#      Year  Jan  Feb  Mar  Apr   May   Jun   Jul   Aug   Sep   Oct   Nov   Dec  \
# 0    1880  -34  -27  -22  -30   -16   -24   -19   -12   -20   -19   -16   -21
# 1    1881  -13  -16   -2   -3    -3   -27   -12    -8   -18   -23   -28   -18
# 2    1882    3    4   -2  -24   -20   -32   -27   -11   -11   -25   -25   -37
# 3    1883  -38  -38  -12  -20   -20    -8    -3   -13   -19   -19   -28   -21
# 4    1884  -20  -14  -31  -36   -33   -36   -31   -24   -29   -25   -29   -25
# 5    1885  -57  -29  -19  -36   -35   -40   -28   -24   -17   -14   -14     0
# 6    1886  -37  -43  -34  -23   -21   -30   -13   -21   -12   -22   -29   -18
# 7    1887  -60  -43  -26  -34   -28   -25   -19   -28   -24   -33   -29   -40
# ..    ...  ...  ...  ...  ...   ...   ...   ...   ...   ...   ...   ...   ...
# 135  2009   56   48   49   57    59    62    66    61    64    58    72    58
# 136  2010   66   75   87   82    71    60    56    59    55    65    74    44
# 137  2011   45   44   57   60    47    54    70    69    52    60    50    48
# 138  2012   38   43   52   62    71    59    50    56    68    73    69    46
# 139  2013   62   52   60   48    56    61    53    61    73    61    75    61
# 140  2014   68   44   71   72    79    62    50    74    81    78    64    74
# 141  2015   75   80   84   71  ****  ****  ****  ****  ****  ****  ****  ****
# 142  Year  Jan  Feb  Mar  Apr   May   Jun   Jul   Aug   Sep   Oct   Nov   Dec
#
#       J-D  D-N   DJF   MAM   JJA   SON Year.1
# 0     -22  ***  ****   -23   -18   -18   1880
# 1     -14  -14   -17    -3   -15   -23   1881
# 2     -17  -16    -4   -15   -23   -20   1882
# 3     -20  -21   -38   -18    -8   -22   1883
# 4     -28  -28   -18   -33   -31   -28   1884
# 5     -26  -28   -37   -30   -31   -15   1885
# 6     -25  -24   -26   -26   -21   -21   1886
# 7     -32  -30   -40   -29   -24   -28   1887
# ..    ...  ...   ...   ...   ...   ...    ...
# 135    59   59    52    55    63    65   2009
# 136    66   67    66    80    58    65   2010
# 137    55   55    45    55    64    54   2011
# 138    57   57    43    62    55    70   2012
# 139    60   59    53    55    58    70   2013
# 140    68   67    58    74    62    74   2014
# 141  ****  ***    76  ****  ****  ****   2015
# 142   J-D  D-N   DJF   MAM   JJA   SON   Year
#
# [143 rows x 20 columns]

# %%
# %more data/greenhouse_gaz/co2_mm_global.txt

# %%
# parse_dates acepta columnas con multiples fechas (lista de fechas), o una fecha de multiples
#columnas (lista de listas)
tablas_en_pagina= pd.read_table("data/greenhouse_gaz/co2_mm_global.txt", sep='\s+', parse_dates=[0])
tablas_en_pagina
# Out:
#           year  month   decimal  average   trend
# 0   1980-01-01      1  1980.042   338.45  337.82
# 1   1980-01-01      2  1980.125   339.17  338.12
# 2   1980-01-01      3  1980.208   339.49  338.14
# 3   1980-01-01      4  1980.292   339.87  338.25
# 4   1980-01-01      5  1980.375   340.30  338.78
# 5   1980-01-01      6  1980.458   339.86  339.08
# 6   1980-01-01      7  1980.542   338.32  339.17
# 7   1980-01-01      8  1980.625   337.11  339.37
# ..         ...    ...       ...      ...     ...
# 416 2014-01-01      9  2014.708   394.90  397.61
# 417 2014-01-01     10  2014.792   396.18  397.63
# 418 2014-01-01     11  2014.875   397.69  397.90
# 419 2014-01-01     12  2014.958   398.62  398.08
# 420 2015-01-01      1  2015.042   399.31  398.29
# 421 2015-01-01      2  2015.125   400.01  398.59
# 422 2015-01-01      3  2015.208   400.59  398.96
# 423 2015-01-01      4  2015.292   401.24  399.41
#
# [424 rows x 5 columns]

# %%
tables = pd.read_html("http://www.psmsl.org/data/obtaining/")
tables
msl=tables[0]

# %%
msl.dtypes
# Out:
# Station Name     object
# ID                int64
# Lat.            float64
# Lon.            float64
# GLOSS ID        float64
# Country          object
# Date             object
# Coastline         int64
# Station           int64
# dtype: object

# %%
type(msl.values)
# Out:
# numpy.ndarray

# %%
np.random.random((50,2))
# Out:
# array([[ 0.72453165,  0.68910613],
#        [ 0.47736744,  0.90782971],
#        [ 0.15668352,  0.48040083],
#        [ 0.18025757,  0.48769084],
#        [ 0.1299684 ,  0.43295299],
#        [ 0.76345202,  0.45722708],
#        [ 0.07078022,  0.72776375],
#        [ 0.57272384,  0.84823641],
#        [ 0.95944363,  0.16824117],
#        [ 0.67270793,  0.18655826],
#        [ 0.40792602,  0.74305782],
#        [ 0.80879333,  0.79092997],
#        [ 0.67173143,  0.44813406],
#        [ 0.58239726,  0.89418084],
#        [ 0.74987441,  0.06802118],
#        [ 0.92472105,  0.78365467],
#        [ 0.99335187,  0.27728629],
#        [ 0.65605367,  0.43700503],
#        [ 0.1570955 ,  0.60994843],
#        [ 0.77684672,  0.94903307],
#        [ 0.64475872,  0.29660687],
#        [ 0.19396541,  0.68542294],
#        [ 0.71955893,  0.92841928],
#        [ 0.35686134,  0.19039873],
#        [ 0.65078308,  0.84698083],
#        [ 0.66515382,  0.10695592],
#        [ 0.47039114,  0.00554331],
#        [ 0.0153094 ,  0.80539258],
#        [ 0.79543913,  0.79862257],
#        [ 0.84530736,  0.75903522],
#        [ 0.35877735,  0.81159488],
#        [ 0.22700795,  0.24716269],
#        [ 0.24699412,  0.15759428],
#        [ 0.72161191,  0.30106557],
#        [ 0.82525345,  0.56899667],
#        [ 0.31269996,  0.45409921],
#        [ 0.96078013,  0.23826926],
#        [ 0.43980911,  0.17657747],
#        [ 0.04476711,  0.71552149],
#        [ 0.12012212,  0.36980606],
#        [ 0.09140677,  0.09901589],
#        [ 0.53393295,  0.04572625],
#        [ 0.09414087,  0.44022578],
#        [ 0.04604711,  0.18497588],
#        [ 0.05123718,  0.38800251],
#        [ 0.9543698 ,  0.75564998],
#        [ 0.16199693,  0.93372454],
#        [ 0.0771641 ,  0.94161478],
#        [ 0.60425114,  0.73089317],
#        [ 0.19079062,  0.8644954 ]])

# %%
r = pd.DataFrame(data=np.random.random((50,2)), columns=['a','b'])
r['c']=r['a'].shift(3)
r
# Out:
#            a         b         c
# 0   0.058496  0.777847       NaN
# 1   0.057426  0.780672       NaN
# 2   0.928169  0.725561       NaN
# 3   0.072440  0.083517  0.058496
# 4   0.685624  0.291912  0.057426
# 5   0.071335  0.571492  0.928169
# 6   0.953621  0.149294  0.072440
# 7   0.253614  0.079950  0.685624
# ..       ...       ...       ...
# 42  0.540247  0.362835  0.532527
# 43  0.860624  0.717839  0.530115
# 44  0.701555  0.337087  0.568474
# 45  0.581150  0.708762  0.540247
# 46  0.867888  0.836017  0.860624
# 47  0.557701  0.201934  0.701555
# 48  0.447098  0.174200  0.581150
# 49  0.551862  0.224460  0.867888
#
# [50 rows x 3 columns]

# %%
rand = pd.DataFrame(data=np.random.random((500000,2)), columns=['a','b'])
rand['c']=rand['a'].shift(1024)
rand.plot.scatter(x='a',y='c',s=.0001)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.4/lib/python3.4/site-packages/matplotlib/collections.py:571: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == str('face'):
